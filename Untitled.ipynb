# %%
import seaborn
import pandas as pd
import matplotlib.pyplot as plt

# %%
jan_2021_data= pd.read_csv ("C:/Users/titil/Documents/UNI -GEO/CEGE0042 Spatial-Temporal Data Analysis and Data Mining (STDM)/Spatial Temporal data/Police data/QGIS_CSV_JAN_2021.csv")
df_march_2020 = pd.read_csv ('C:/Users/titil/Documents/UNI -GEO/CEGE0042 Spatial-Temporal Data Analysis and Data Mining (STDM)/Spatial Temporal data/Police data/qgis_march_2020.csv')
seaborn.set_theme(style="dark")

# %%
jan_2021_data
# Out:
#                                                 Crime ID    Month  Longitude  \
# 0      d3199dcf54f2ef0f777bdea4098dacf6e8793710c40c77...  2021-01   0.140192
# 1      af7eff994baf5ef5549506978d5a94232c2ea3ae80fd1b...  2021-01   0.127683
# 2      2d958ae976b86d4a724c5db964a0be78ada85db2aa9ef0...  2021-01   0.127683
# 3      af7eff994baf5ef5549506978d5a94232c2ea3ae80fd1b...  2021-01   0.127683
# 4      af7eff994baf5ef5549506978d5a94232c2ea3ae80fd1b...  2021-01   0.127683
# ...                                                  ...      ...        ...
# 16043  9648ad98360e717261050c215e6d903f06e27abb9c4575...  2021-01  -0.137907
# 16044  9648ad98360e717261050c215e6d903f06e27abb9c4575...  2021-01  -0.137907
# 16045  b28f7517dc75d08058c7a0de5342543a8e6e7556aae355...  2021-01  -0.137231
# 16046  d1052ee8ee11878bc46277545dff96f5b424ed7055f766...  2021-01  -0.134554
# 16047  9a983f76e6dca1cc42bb1103f30e206af9ce040ac8fc98...  2021-01  -0.135532
#
#         Latitude                       LSOA
# 0      51.582311  Barking and Dagenham 001A
# 1      51.585524  Barking and Dagenham 001B
# 2      51.585524  Barking and Dagenham 001B
# 3      51.585524  Barking and Dagenham 001B
# 4      51.585524  Barking and Dagenham 001B
# ...          ...                        ...
# 16043  51.486679           Westminster 024D
# 16044  51.486679           Westminster 024D
# 16045  51.486309           Westminster 024E
# 16046  51.490475           Westminster 024F
# 16047  51.489097           Westminster 024F
#
# [16048 rows x 5 columns]

# %%
df_march_2020

# %%
seaborn.jointplot('Longitude','Latitude',jan_2021_data,kind='kde')
# Out:
# C:\Users\titil\anaconda3\envs\forall\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
